# %% [markdown]
# # Análise exploratória dos dados (EDA)
#
# Esta análise exploratória tem como objetivo conhecer melhor o conjunto de dados de anúncios de veículos. Nesta etapa, serão observadas as principais características dos dados, como quantidade de registros, tipos de dados, valores ausentes, possíveis duplicados e comportamento de algumas variáveis importantes.
#
# Também serão criados gráficos interativos para visualizar a distribuição da quilometragem dos veículos, a distribuição dos preços e a relação entre preço e quilometragem. Essa etapa ajuda a entender melhor os dados antes da criação do aplicativo web em Streamlit.

# %%
## 1.Importação das bibliotecas

import pandas as pd
import plotly.express as px

# %%
## 2.Carregamento dos dados

car_data = pd.read_csv('../vehicles.csv')

car_data.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV         NaN     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     NaN  2019-02-07           79
# 3    automatic  pickup         NaN     NaN  2019-03-22            9
# 4    automatic   sedan       black     NaN  2019-04-02           28

# %%
## 3. Visão geral dos dados

car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %%
## 4. Valores ausentes

car_data.isna().sum()
# Out:
# price               0
# model_year       3619
# model               0
# condition           0
# cylinders        5260
# fuel                0
# odometer         7892
# transmission        0
# type                0
# paint_color      9267
# is_4wd          25953
# date_posted         0
# days_listed         0
# dtype: int64

# %%
## 5. Valores duplicados

car_data.duplicated().sum()
# Out:
# 0

# %%
## 6. Distribuição da quilometragem

fig = px.histogram(
    car_data,
    x='odometer',
    title='Distribuição da quilometragem dos veículos',
    labels={'odometer': 'Quilometragem'})

fig.show()

# %%
## 7. Distribuição dos preços

fig = px.histogram(
    car_data,
    x='price',
    title='Distribuição dos preços dos veículos',
    labels={'price': 'Preço'})

fig.show()

# %%
## 8. Relação entre preço e quilometragem

fig = px.scatter(
    car_data,
    x='odometer',
    y='price',
    title='Relação entre quilometragem e preço',
    labels={'odometer': 'Quilometragem', 'price': 'Preço'})

fig.show()

# %%
## 9. Relação entre quilometragem e preço por tipo de veículo

fig = px.scatter(
    car_data,
    x='odometer',
    y='price',
    color='type',
    title='Relação entre quilometragem e preço por tipo de veículo',
    labels={'odometer': 'Quilometragem', 'price': 'Preço', 'type': 'Tipo'})

fig.show()

# %%
## 10. Contagem por tipo de veículo

type_counts = car_data['type'].value_counts().reset_index()
type_counts.columns = ['type', 'count']

fig = px.bar(
    type_counts,
    x='type',
    y='count',
    title='Quantidade de anúncios por tipo de veículo',
    labels={'type': 'Tipo de veículo', 'count': 'Quantidade de anúncios'})

fig.show()

# %% [markdown]
# ## 11. Conclusão da EDA
#
#
#
# Nesta análise exploratória inicial, foram avaliadas as principais características do conjunto de dados de anúncios de veículos.
#
# Foram verificadas informações gerais dos dados, valores ausentes e possíveis duplicados. Também foram criados gráficos interativos com Plotly Express para observar a distribuição da quilometragem, a distribuição dos preços, a relação entre preço e quilometragem e a quantidade de anúncios por tipo de veículo.
#
# A análise gráfica mostra que o conjunto de dados pode ser usado para construir um aplicativo web simples em Streamlit, permitindo ao usuário visualizar padrões nos anúncios de veículos e explorar a relação entre variáveis como preço, quilometragem e tipo de veículo.
